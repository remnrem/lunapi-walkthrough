# %% [markdown]
# URL index: [Home](https://zzz.bwh.harvard.edu/luna-walkthrough/) | [Data](https://zzz.bwh.harvard.edu/luna-walkthrough/data/) | [S1. File QC](https://zzz.bwh.harvard.edu/luna-walkthrough/p1/) | [S2. Signal QC](https://zzz.bwh.harvard.edu/luna-walkthrough/p2) | [S3. Staging](https://zzz.bwh.harvard.edu/luna-walkthrough/p3) | [S4. Artifacts](https://zzz.bwh.harvard.edu/luna-walkthrough/p4) | [S5. Analysis](https://zzz.bwh.harvard.edu/luna-walkthrough/p5)
#
# Notebook index: [Index](../00_index.ipynb) | [S1. File QC](../p1/00_index.ipynb) | [S2. Signal QC](../p2/00_index.ipynb) | [S3. Staging](../p3/00_index.ipynb) | [S4. Artifacts](../p4/00_index.ipynb) | [S5. Analysis](../p5/00_index.ipynb)
#
# ---

# %% [markdown]
# # 1.6. Reviewing and harmonizing channel labels
#
# Walkthrough URL = [https://zzz.bwh.harvard.edu/luna-walkthrough/p1/chs/](https://zzz.bwh.harvard.edu/luna-walkthrough/p1/chs/)

# %%
import lunapi as lp
proj = lp.proj()
proj.sample_list( 's1.lst' )
# Out:
# initiated lunapi v0.1.1 <lunapi.lunapi0.luna object at 0x14a1766f0>
#
# read 20 individuals from s1.lst

# %% [markdown]
# We will re-run `HEADERS` to get a list of all channel information.

# %%
res = proj.silent_proc( 'HEADERS' )

# %% [markdown]
# ## Labels

# %% [markdown]
# Display a list of channels, with sample rate (`SR`) and unit (`PDIM`) also.

# %%
# destrat out.db +HEADERS -r CH -v SR PDIM
#import pandas as pd
#pd.set_option('display.max_rows', 20 )
tbl = proj.table( 'HEADERS', 'CH' )[[ 'CH', 'SR', 'PDIM' ]]
tbl
# Out:
#        CH     SR PDIM
# 0      A1  128.0   uV
# 1      A1  150.0   uV
# 2      A1  128.0   mV
# 3      A1  128.0   uV
# 4      A1  128.0   uV
# ...   ...    ...  ...
# 1172   pz  128.0   uV
# 1173   t7  128.0   uV
# 1174   t8  128.0   uV
# 1175  tp7  128.0   uV
# 1176  tp8  128.0   uV
#
# [1177 rows x 3 columns]

# %% [markdown]
# To get a list of all unique channel labels.

# %%
tbl['CH'].unique()
# Out:
# array(['A1', 'A1_REF', 'A2', 'A2_REF', 'AF3', 'AF3_REF', 'AF3__M1_M2__2',
#        'AF4', 'AF4_REF', 'AF4__M1_M2__2', 'AFZ', 'AFZ_REF',
#        'AFZ__M1_M2__2', 'C1', 'C1_REF', 'C1__M1_M2__2', 'C2', 'C2_REF',
#        'C2__M1_M2__2', 'C3', 'C3_REF', 'C3__M1_M2__2', 'C4', 'C4_REF',
#        'C4__M1_M2__2', 'C5', 'C5_REF', 'C5__M1_M2__2', 'C6', 'C6_REF',
#        'C6__M1_M2__2', 'CP1', 'CP1_REF', 'CP1__M1_M2__2', 'CP2',
#        'CP2_REF', 'CP2__M1_M2__2', 'CP3', 'CP3_REF', 'CP3__M1_M2__2',
#        'CP4', 'CP4_REF', 'CP4__M1_M2__2', 'CP5', 'CP5_REF',
#        'CP5__M1_M2__2', 'CP6', 'CP6_REF', 'CP6__M1_M2__2', 'CPZ',
#        'CPZ_REF', 'CPZ__M1_M2__2', 'CZ', 'CZ_REF', 'CZ__M1_M2__2',
#        'EEG_A1', 'EEG_A2', 'EEG_AF3', 'EEG_AF4', 'EEG_AFZ', 'EEG_C1',
#        'EEG_C2', 'EEG_C3', 'EEG_C4', 'EEG_C5', 'EEG_C6', 'EEG_CP1',
#        'EEG_CP2', 'EEG_CP3', 'EEG_CP4', 'EEG_CP5', 'EEG_CP6', 'EEG_CPZ',
#        'EEG_CZ', 'EEG_F1', 'EEG_F2', 'EEG_F3', 'EEG_F4', 'EEG_F5',
#        'EEG_F6', 'EEG_F7', 'EEG_F8', 'EEG_FC1', 'EEG_FC2', 'EEG_FC3',
#        'EEG_FC4', 'EEG_FC5', 'EEG_FC6', 'EEG_FCZ', 'EEG_FPZ', 'EEG_FT7',
#        'EEG_FT8', 'EEG_FZ', 'EEG_Fp1', 'EEG_Fp2', 'EEG_O1', 'EEG_O2',
#        'EEG_OZ', 'EEG_P1', 'EEG_P2', 'EEG_P3', 'EEG_P4', 'EEG_P5',
#        'EEG_P6', 'EEG_P7', 'EEG_P8', 'EEG_PO3', 'EEG_PO4', 'EEG_POz',
#        'EEG_PZ', 'EEG_T7', 'EEG_T8', 'EEG_TP7', 'EEG_TP8', 'F1', 'F1_REF',
#        'F1__M1_M2__2', 'F2', 'F2_REF', 'F2__M1_M2__2', 'F3', 'F3_REF',
#        'F3__M1_M2__2', 'F4', 'F4_REF', 'F4__M1_M2__2', 'F5', 'F5_REF',
#        'F5__M1_M2__2', 'F6', 'F6_REF', 'F6__M1_M2__2', 'F7', 'F7_REF',
#        'F7__M1_M2__2', 'F8', 'F8_REF', 'F8__M1_M2__2', 'FC1', 'FC1_REF',
#        'FC1__M1_M2__2', 'FC2', 'FC2_REF', 'FC2__M1_M2__2', 'FC3',
#        'FC3_REF', 'FC3__M1_M2__2', 'FC4', 'FC4_REF', 'FC4__M1_M2__2',
#        'FC5', 'FC5_REF', 'FC5__M1_M2__2', 'FC6', 'FC6_REF',
#        'FC6__M1_M2__2', 'FCZ', 'FCZ_REF', 'FCZ__M1_M2__2', 'FP1', 'FP2',
#        'FPZ', 'FPZ_REF', 'FPZ__M1_M2__2', 'FT7', 'FT7_REF',
#        'FT7__M1_M2__2', 'FT8', 'FT8_REF', 'FT8__M1_M2__2', 'FZ', 'FZ_REF',
#        'FZ__M1_M2__2', 'Fp1', 'Fp1_REF', 'Fp1__M1_M2__2', 'Fp2',
#        'Fp2_REF', 'Fp2__M1_M2__2', 'O1', 'O1_REF', 'O1__M1_M2__2', 'O2',
#        'O2_REF', 'O2__M1_M2__2', 'OZ', 'OZ_REF', 'OZ__M1_M2__2', 'P1',
#        'P1_REF', 'P1__M1_M2__2', 'P2', 'P2_REF', 'P2__M1_M2__2', 'P3',
#        'P3_REF', 'P3__M1_M2__2', 'P4', 'P4_REF', 'P4__M1_M2__2', 'P5',
#        'P5_REF', 'P5__M1_M2__2', 'P6', 'P6_REF', 'P6__M1_M2__2', 'P7',
#        'P7_REF', 'P7__M1_M2__2', 'P8', 'P8_REF', 'P8__M1_M2__2', 'PO3',
#        'PO3_REF', 'PO3__M1_M2__2', 'PO4', 'PO4_REF', 'PO4__M1_M2__2',
#        'POZ', 'POz', 'POz_REF', 'POz__M1_M2__2', 'PZ', 'PZ_REF',
#        'PZ__M1_M2__2', 'T7', 'T7_REF', 'T7__M1_M2__2', 'T8', 'T8_REF',
#        'T8__M1_M2__2', 'TP7', 'TP7_REF', 'TP7__M1_M2__2', 'TP8',
#        'TP8_REF', 'TP8__M1_M2__2', 'a1', 'a2', 'af3', 'af4', 'afz', 'c1',
#        'c2', 'c3', 'c4', 'c5', 'c6', 'cp1', 'cp2', 'cp3', 'cp4', 'cp5',
#        'cp6', 'cpz', 'cz', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8',
#        'fc1', 'fc2', 'fc3', 'fc4', 'fc5', 'fc6', 'fcz', 'fp1', 'fp2',
#        'fpz', 'ft7', 'ft8', 'fz', 'o1', 'o2', 'oz', 'p1', 'p2', 'p3',
#        'p4', 'p5', 'p6', 'p7', 'p8', 'po3', 'po4', 'poz', 'pz', 't7',
#        't8', 'tp7', 'tp8'], dtype=object)

# %% [markdown]
# To count and pretty-print the above list.

# %%
tbl.groupby(['CH']).size().reset_index(name='Count')
# Out:
#          CH  Count
# 0        A1     16
# 1    A1_REF      1
# 2        A2     16
# 3    A2_REF      1
# 4       AF3     16
# ..      ...    ...
# 291      pz      1
# 292      t7      1
# 293      t8      1
# 294     tp7      1
# 295     tp8      1
#
# [296 rows x 2 columns]

# %% [markdown]
# One Python/pandas way to print the full table.

# %%
import pandas as pd
with pd.option_context('display.max_rows', None,):
    display( tbl.groupby(['CH']).size().reset_index(name='Count') )
# Out:
#                 CH  Count
# 0               A1     16
# 1           A1_REF      1
# 2               A2     16
# 3           A2_REF      1
# 4              AF3     16
# 5          AF3_REF      1
# 6    AF3__M1_M2__2      1
# 7              AF4     16
# 8          AF4_REF      1
# 9    AF4__M1_M2__2      1
# 10             AFZ     16
# 11         AFZ_REF      1
# 12   AFZ__M1_M2__2      1
# 13              C1     16
# 14          C1_REF      1
# 15    C1__M1_M2__2      1
# 16              C2     16
# 17          C2_REF      1
# 18    C2__M1_M2__2      1
# 19              C3     16
# 20          C3_REF      1
# 21    C3__M1_M2__2      1
# 22              C4     16
# 23          C4_REF      1
# 24    C4__M1_M2__2      1
# 25              C5     16
# 26          C5_REF      1
# 27    C5__M1_M2__2      1
# 28              C6     16
# 29          C6_REF      1
# 30    C6__M1_M2__2      1
# 31             CP1     16
# 32         CP1_REF      1
# 33   CP1__M1_M2__2      1
# 34             CP2     16
# 35         CP2_REF      1
# 36   CP2__M1_M2__2      1
# 37             CP3     16
# 38         CP3_REF      1
# 39   CP3__M1_M2__2      1
# 40             CP4     16
# 41         CP4_REF      1
# 42   CP4__M1_M2__2      1
# 43             CP5     16
# 44         CP5_REF      1
# 45   CP5__M1_M2__2      1
# 46             CP6     16
# 47         CP6_REF      1
# 48   CP6__M1_M2__2      1
# 49             CPZ     16
# 50         CPZ_REF      1
# 51   CPZ__M1_M2__2      1
# 52              CZ     15
# 53          CZ_REF      1
# 54    CZ__M1_M2__2      1
# 55          EEG_A1      1
# 56          EEG_A2      1
# 57         EEG_AF3      1
# 58         EEG_AF4      1
# 59         EEG_AFZ      1
# 60          EEG_C1      1
# 61          EEG_C2      1
# 62          EEG_C3      1
# 63          EEG_C4      1
# 64          EEG_C5      1
# 65          EEG_C6      1
# 66         EEG_CP1      1
# 67         EEG_CP2      1
# 68         EEG_CP3      1
# 69         EEG_CP4      1
# 70         EEG_CP5      1
# 71         EEG_CP6      1
# 72         EEG_CPZ      1
# 73          EEG_CZ      1
# 74          EEG_F1      1
# 75          EEG_F2      1
# 76          EEG_F3      1
# 77          EEG_F4      1
# 78          EEG_F5      1
# 79          EEG_F6      1
# 80          EEG_F7      1
# 81          EEG_F8      1
# 82         EEG_FC1      1
# 83         EEG_FC2      1
# 84         EEG_FC3      1
# 85         EEG_FC4      1
# 86         EEG_FC5      1
# 87         EEG_FC6      1
# 88         EEG_FCZ      1
# 89         EEG_FPZ      1
# 90         EEG_FT7      1
# 91         EEG_FT8      1
# 92          EEG_FZ      1
# 93         EEG_Fp1      1
# 94         EEG_Fp2      1
# 95          EEG_O1      1
# 96          EEG_O2      1
# 97          EEG_OZ      1
# 98          EEG_P1      1
# 99          EEG_P2      1
# 100         EEG_P3      1
# 101         EEG_P4      1
# 102         EEG_P5      1
# 103         EEG_P6      1
# 104         EEG_P7      1
# 105         EEG_P8      1
# 106        EEG_PO3      1
# 107        EEG_PO4      1
# 108        EEG_POz      1
# 109         EEG_PZ      1
# 110         EEG_T7      1
# 111         EEG_T8      1
# 112        EEG_TP7      1
# 113        EEG_TP8      1
# 114             F1     16
# 115         F1_REF      1
# 116   F1__M1_M2__2      1
# 117             F2     16
# 118         F2_REF      1
# 119   F2__M1_M2__2      1
# 120             F3     16
# 121         F3_REF      1
# 122   F3__M1_M2__2      1
# 123             F4     16
# 124         F4_REF      1
# 125   F4__M1_M2__2      1
# 126             F5     16
# 127         F5_REF      1
# 128   F5__M1_M2__2      1
# 129             F6     16
# 130         F6_REF      1
# 131   F6__M1_M2__2      1
# 132             F7     16
# 133         F7_REF      1
# 134   F7__M1_M2__2      1
# 135             F8     16
# 136         F8_REF      1
# 137   F8__M1_M2__2      1
# 138            FC1     16
# 139        FC1_REF      1
# 140  FC1__M1_M2__2      1
# 141            FC2     16
# 142        FC2_REF      1
# 143  FC2__M1_M2__2      1
# 144            FC3     16
# 145        FC3_REF      1
# 146  FC3__M1_M2__2      1
# 147            FC4     16
# 148        FC4_REF      1
# 149  FC4__M1_M2__2      1
# 150            FC5     16
# 151        FC5_REF      1
# 152  FC5__M1_M2__2      1
# 153            FC6     16
# 154        FC6_REF      1
# 155  FC6__M1_M2__2      1
# 156            FCZ     16
# 157        FCZ_REF      1
# 158  FCZ__M1_M2__2      1
# 159            FP1      1
# 160            FP2      1
# 161            FPZ     16
# 162        FPZ_REF      1
# 163  FPZ__M1_M2__2      1
# 164            FT7     16
# 165        FT7_REF      1
# 166  FT7__M1_M2__2      1
# 167            FT8     16
# 168        FT8_REF      1
# 169  FT8__M1_M2__2      1
# 170             FZ     16
# 171         FZ_REF      1
# 172   FZ__M1_M2__2      1
# 173            Fp1     15
# 174        Fp1_REF      1
# 175  Fp1__M1_M2__2      1
# 176            Fp2     15
# 177        Fp2_REF      1
# 178  Fp2__M1_M2__2      1
# 179             O1     16
# 180         O1_REF      1
# 181   O1__M1_M2__2      1
# 182             O2     16
# 183         O2_REF      1
# 184   O2__M1_M2__2      1
# 185             OZ     16
# 186         OZ_REF      1
# 187   OZ__M1_M2__2      1
# 188             P1     16
# 189         P1_REF      1
# 190   P1__M1_M2__2      1
# 191             P2     16
# 192         P2_REF      1
# 193   P2__M1_M2__2      1
# 194             P3     16
# 195         P3_REF      1
# 196   P3__M1_M2__2      1
# 197             P4     16
# 198         P4_REF      1
# 199   P4__M1_M2__2      1
# 200             P5     16
# 201         P5_REF      1
# 202   P5__M1_M2__2      1
# 203             P6     16
# 204         P6_REF      1
# 205   P6__M1_M2__2      1
# 206             P7     16
# 207         P7_REF      1
# 208   P7__M1_M2__2      1
# 209             P8     16
# 210         P8_REF      1
# 211   P8__M1_M2__2      1
# 212            PO3     16
# 213        PO3_REF      1
# 214  PO3__M1_M2__2      1
# 215            PO4     16
# 216        PO4_REF      1
# 217  PO4__M1_M2__2      1
# 218            POZ      1
# 219            POz     15
# 220        POz_REF      1
# 221  POz__M1_M2__2      1
# 222             PZ     16
# 223         PZ_REF      1
# 224   PZ__M1_M2__2      1
# 225             T7     16
# 226         T7_REF      1
# 227   T7__M1_M2__2      1
# 228             T8     16
# 229         T8_REF      1
# 230   T8__M1_M2__2      1
# 231            TP7     16
# 232        TP7_REF      1
# 233  TP7__M1_M2__2      1
# 234            TP8     16
# 235        TP8_REF      1
# 236  TP8__M1_M2__2      1
# 237             a1      1
# 238             a2      1
# 239            af3      1
# 240            af4      1
# 241            afz      1
# 242             c1      1
# 243             c2      1
# 244             c3      1
# 245             c4      1
# 246             c5      1
# 247             c6      1
# 248            cp1      1
# 249            cp2      1
# 250            cp3      1
# 251            cp4      1
# 252            cp5      1
# 253            cp6      1
# 254            cpz      1
# 255             cz      1
# 256             f1      1
# 257             f2      1
# 258             f3      1
# 259             f4      1
# 260             f5      1
# 261             f6      1
# 262             f7      1
# 263             f8      1
# 264            fc1      1
# 265            fc2      1
# 266            fc3      1
# 267            fc4      1
# 268            fc5      1
# 269            fc6      1
# 270            fcz      1
# 271            fp1      1
# 272            fp2      1
# 273            fpz      1
# 274            ft7      1
# 275            ft8      1
# 276             fz      1
# 277             o1      1
# 278             o2      1
# 279             oz      1
# 280             p1      1
# 281             p2      1
# 282             p3      1
# 283             p4      1
# 284             p5      1
# 285             p6      1
# 286             p7      1
# 287             p8      1
# 288            po3      1
# 289            po4      1
# 290            poz      1
# 291             pz      1
# 292             t7      1
# 293             t8      1
# 294            tp7      1
# 295            tp8      1

# %% [markdown]
# ## Sanitized versus original labels

# %% [markdown]
# To turn off the default _sanitization_ of channel labels by Luna.

# %%
proj.var( 'sanitize' , 'F' )
proj.var( 'keep-spaces' , 'T' )

# %% [markdown]
# If we re-run `HEADERS` labels will now be printed _as is_.

# %%
res = proj.silent_proc( 'HEADERS signals' )

# %% [markdown]
# Get a list of all unique labels:

# %%
tbl = proj.table( 'HEADERS', 'CH' )[[ 'CH', 'SR', 'PDIM' ]]
tbl['CH'].unique()
# Out:
# array(['A1', 'A1 REF', 'A2', 'A2 REF', 'AF3', 'AF3 REF', 'AF3-(M1+M2)/2',
#        'AF4', 'AF4 REF', 'AF4-(M1+M2)/2', 'AFZ', 'AFZ REF',
#        'AFZ-(M1+M2)/2', 'C1', 'C1 REF', 'C1-(M1+M2)/2', 'C2', 'C2 REF',
#        'C2-(M1+M2)/2', 'C3', 'C3 REF', 'C3-(M1+M2)/2', 'C4', 'C4 REF',
#        'C4-(M1+M2)/2', 'C5', 'C5 REF', 'C5-(M1+M2)/2', 'C6', 'C6 REF',
#        'C6-(M1+M2)/2', 'CP1', 'CP1 REF', 'CP1-(M1+M2)/2', 'CP2',
#        'CP2 REF', 'CP2-(M1+M2)/2', 'CP3', 'CP3 REF', 'CP3-(M1+M2)/2',
#        'CP4', 'CP4 REF', 'CP4-(M1+M2)/2', 'CP5', 'CP5 REF',
#        'CP5-(M1+M2)/2', 'CP6', 'CP6 REF', 'CP6-(M1+M2)/2', 'CPZ',
#        'CPZ REF', 'CPZ-(M1+M2)/2', 'CZ', 'CZ REF', 'CZ-(M1+M2)/2',
#        'EEG-A1', 'EEG-A2', 'EEG-AF3', 'EEG-AF4', 'EEG-AFZ', 'EEG-C1',
#        'EEG-C2', 'EEG-C3', 'EEG-C4', 'EEG-C5', 'EEG-C6', 'EEG-CP1',
#        'EEG-CP2', 'EEG-CP3', 'EEG-CP4', 'EEG-CP5', 'EEG-CP6', 'EEG-CPZ',
#        'EEG-CZ', 'EEG-F1', 'EEG-F2', 'EEG-F3', 'EEG-F4', 'EEG-F5',
#        'EEG-F6', 'EEG-F7', 'EEG-F8', 'EEG-FC1', 'EEG-FC2', 'EEG-FC3',
#        'EEG-FC4', 'EEG-FC5', 'EEG-FC6', 'EEG-FCZ', 'EEG-FPZ', 'EEG-FT7',
#        'EEG-FT8', 'EEG-FZ', 'EEG-Fp1', 'EEG-Fp2', 'EEG-O1', 'EEG-O2',
#        'EEG-OZ', 'EEG-P1', 'EEG-P2', 'EEG-P3', 'EEG-P4', 'EEG-P5',
#        'EEG-P6', 'EEG-P7', 'EEG-P8', 'EEG-PO3', 'EEG-PO4', 'EEG-POz',
#        'EEG-PZ', 'EEG-T7', 'EEG-T8', 'EEG-TP7', 'EEG-TP8', 'F1', 'F1 REF',
#        'F1-(M1+M2)/2', 'F2', 'F2 REF', 'F2-(M1+M2)/2', 'F3', 'F3 REF',
#        'F3-(M1+M2)/2', 'F4', 'F4 REF', 'F4-(M1+M2)/2', 'F5', 'F5 REF',
#        'F5-(M1+M2)/2', 'F6', 'F6 REF', 'F6-(M1+M2)/2', 'F7', 'F7 REF',
#        'F7-(M1+M2)/2', 'F8', 'F8 REF', 'F8-(M1+M2)/2', 'FC1', 'FC1 REF',
#        'FC1-(M1+M2)/2', 'FC2', 'FC2 REF', 'FC2-(M1+M2)/2', 'FC3',
#        'FC3 REF', 'FC3-(M1+M2)/2', 'FC4', 'FC4 REF', 'FC4-(M1+M2)/2',
#        'FC5', 'FC5 REF', 'FC5-(M1+M2)/2', 'FC6', 'FC6 REF',
#        'FC6-(M1+M2)/2', 'FCZ', 'FCZ REF', 'FCZ-(M1+M2)/2', 'FP1', 'FP2',
#        'FPZ', 'FPZ REF', 'FPZ-(M1+M2)/2', 'FT7', 'FT7 REF',
#        'FT7-(M1+M2)/2', 'FT8', 'FT8 REF', 'FT8-(M1+M2)/2', 'FZ', 'FZ REF',
#        'FZ-(M1+M2)/2', 'Fp1', 'Fp1 REF', 'Fp1-(M1+M2)/2', 'Fp2',
#        'Fp2 REF', 'Fp2-(M1+M2)/2', 'O1', 'O1 REF', 'O1-(M1+M2)/2', 'O2',
#        'O2 REF', 'O2-(M1+M2)/2', 'OZ', 'OZ REF', 'OZ-(M1+M2)/2', 'P1',
#        'P1 REF', 'P1-(M1+M2)/2', 'P2', 'P2 REF', 'P2-(M1+M2)/2', 'P3',
#        'P3 REF', 'P3-(M1+M2)/2', 'P4', 'P4 REF', 'P4-(M1+M2)/2', 'P5',
#        'P5 REF', 'P5-(M1+M2)/2', 'P6', 'P6 REF', 'P6-(M1+M2)/2', 'P7',
#        'P7 REF', 'P7-(M1+M2)/2', 'P8', 'P8 REF', 'P8-(M1+M2)/2', 'PO3',
#        'PO3 REF', 'PO3-(M1+M2)/2', 'PO4', 'PO4 REF', 'PO4-(M1+M2)/2',
#        'POZ', 'POz', 'POz REF', 'POz-(M1+M2)/2', 'PZ', 'PZ REF',
#        'PZ-(M1+M2)/2', 'T7', 'T7 REF', 'T7-(M1+M2)/2', 'T8', 'T8 REF',
#        'T8-(M1+M2)/2', 'TP7', 'TP7 REF', 'TP7-(M1+M2)/2', 'TP8',
#        'TP8 REF', 'TP8-(M1+M2)/2', 'a1', 'a2', 'af3', 'af4', 'afz', 'c1',
#        'c2', 'c3', 'c4', 'c5', 'c6', 'cp1', 'cp2', 'cp3', 'cp4', 'cp5',
#        'cp6', 'cpz', 'cz', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8',
#        'fc1', 'fc2', 'fc3', 'fc4', 'fc5', 'fc6', 'fcz', 'fp1', 'fp2',
#        'fpz', 'ft7', 'ft8', 'fz', 'o1', 'o2', 'oz', 'p1', 'p2', 'p3',
#        'p4', 'p5', 'p6', 'p7', 'p8', 'po3', 'po4', 'poz', 'pz', 't7',
#        't8', 'tp7', 'tp8'], dtype=object)

# %% [markdown]
# We can extract the full combinations of signals _per individual_ from the `SIGNALS` variable.

# %%
tbl = proj.table( 'HEADERS' )[[ 'ID', 'SIGNALS' ]]
tbl
# Out:
#      ID                                            SIGNALS
# 0   F01  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 1   F02  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 2   F03  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 3   F04  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 4   F05  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 5   F06  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 6   F07  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 7   F08  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 8   F09  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 9   F10  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 10  M01  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 11  M02  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 12  M03  Fp1,Fp2,AF3,AF4,F7,F5,F1,F2,F6,F8,FT7,FC5,FC3,...
# 13  M04  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 14  M05  fp1,fp2,af3,af4,f7,f5,f3,f1,f2,f4,f6,f8,ft7,fc...
# 15  M06  FP1,FP2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...
# 16  M07  EEG-Fp1,EEG-Fp2,EEG-AF3,EEG-AF4,EEG-F7,EEG-F5,...
# 17  M08  Fp1 REF,Fp2 REF,AF3 REF,AF4 REF,F7 REF,F5 REF,...
# 18  M09  Fp1-(M1+M2)/2,Fp2-(M1+M2)/2,AF3-(M1+M2)/2,AF4-...
# 19  M10  Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC...

# %% [markdown]
# As above, we can change pandas display defaults (temporarily) to list the full labels.

# %%
with pd.option_context('display.max_colwidth', None):
    display(tbl)
# Out:
#      ID  \
# 0   F01
# 1   F02
# 2   F03
# 3   F04
# 4   F05
# 5   F06
# 6   F07
# 7   F08
# 8   F09
# 9   F10
# 10  M01
# 11  M02
# 12  M03
# 13  M04
# 14  M05
# 15  M06
# 16  M07
# 17  M08
# 18  M09
# 19  M10
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             SIGNALS
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Fp1,Fp2,AF3,AF4,F7,F5,F1,F2,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C1,C2,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P1,P2,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ,C3,C4,F3,F4,P3,P4
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CPZ,PZ,POz,OZ,A1,A2,FPZ
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      fp1,fp2,af3,af4,f7,f5,f3,f1,f2,f4,f6,f8,ft7,fc5,fc3,fc1,fc2,fc4,fc6,ft8,t7,c5,c3,c1,c2,c4,c6,t8,tp7,cp5,cp3,cp1,cp2,cp4,cp6,tp8,p7,p5,p3,p1,p2,p4,p6,p8,po3,po4,o1,o2,afz,fz,fcz,cz,cpz,pz,poz,oz,a1,a2,fpz
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      FP1,FP2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POZ,OZ,A1,A2,FPZ
# 16                                                                                                                                                                                                                                                                                                                                          EEG-Fp1,EEG-Fp2,EEG-AF3,EEG-AF4,EEG-F7,EEG-F5,EEG-F3,EEG-F1,EEG-F2,EEG-F4,EEG-F6,EEG-F8,EEG-FT7,EEG-FC5,EEG-FC3,EEG-FC1,EEG-FC2,EEG-FC4,EEG-FC6,EEG-FT8,EEG-T7,EEG-C5,EEG-C3,EEG-C1,EEG-C2,EEG-C4,EEG-C6,EEG-T8,EEG-TP7,EEG-CP5,EEG-CP3,EEG-CP1,EEG-CP2,EEG-CP4,EEG-CP6,EEG-TP8,EEG-P7,EEG-P5,EEG-P3,EEG-P1,EEG-P2,EEG-P4,EEG-P6,EEG-P8,EEG-PO3,EEG-PO4,EEG-O1,EEG-O2,EEG-AFZ,EEG-FZ,EEG-FCZ,EEG-CZ,EEG-CPZ,EEG-PZ,EEG-POz,EEG-OZ,EEG-A1,EEG-A2,EEG-FPZ
# 17                                                                                                                                                                                                                                                                                                                                          Fp1 REF,Fp2 REF,AF3 REF,AF4 REF,F7 REF,F5 REF,F3 REF,F1 REF,F2 REF,F4 REF,F6 REF,F8 REF,FT7 REF,FC5 REF,FC3 REF,FC1 REF,FC2 REF,FC4 REF,FC6 REF,FT8 REF,T7 REF,C5 REF,C3 REF,C1 REF,C2 REF,C4 REF,C6 REF,T8 REF,TP7 REF,CP5 REF,CP3 REF,CP1 REF,CP2 REF,CP4 REF,CP6 REF,TP8 REF,P7 REF,P5 REF,P3 REF,P1 REF,P2 REF,P4 REF,P6 REF,P8 REF,PO3 REF,PO4 REF,O1 REF,O2 REF,AFZ REF,FZ REF,FCZ REF,CZ REF,CPZ REF,PZ REF,POz REF,OZ REF,A1 REF,A2 REF,FPZ REF
# 18  Fp1-(M1+M2)/2,Fp2-(M1+M2)/2,AF3-(M1+M2)/2,AF4-(M1+M2)/2,F7-(M1+M2)/2,F5-(M1+M2)/2,F3-(M1+M2)/2,F1-(M1+M2)/2,F2-(M1+M2)/2,F4-(M1+M2)/2,F6-(M1+M2)/2,F8-(M1+M2)/2,FT7-(M1+M2)/2,FC5-(M1+M2)/2,FC3-(M1+M2)/2,FC1-(M1+M2)/2,FC2-(M1+M2)/2,FC4-(M1+M2)/2,FC6-(M1+M2)/2,FT8-(M1+M2)/2,T7-(M1+M2)/2,C5-(M1+M2)/2,C3-(M1+M2)/2,C1-(M1+M2)/2,C2-(M1+M2)/2,C4-(M1+M2)/2,C6-(M1+M2)/2,T8-(M1+M2)/2,TP7-(M1+M2)/2,CP5-(M1+M2)/2,CP3-(M1+M2)/2,CP1-(M1+M2)/2,CP2-(M1+M2)/2,CP4-(M1+M2)/2,CP6-(M1+M2)/2,TP8-(M1+M2)/2,P7-(M1+M2)/2,P5-(M1+M2)/2,P3-(M1+M2)/2,P1-(M1+M2)/2,P2-(M1+M2)/2,P4-(M1+M2)/2,P6-(M1+M2)/2,P8-(M1+M2)/2,PO3-(M1+M2)/2,PO4-(M1+M2)/2,O1-(M1+M2)/2,O2-(M1+M2)/2,AFZ-(M1+M2)/2,FZ-(M1+M2)/2,FCZ-(M1+M2)/2,CZ-(M1+M2)/2,CPZ-(M1+M2)/2,PZ-(M1+M2)/2,POz-(M1+M2)/2,OZ-(M1+M2)/2,FPZ-(M1+M2)/2
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,A1,A2,FPZ

# %% [markdown]
# We can count the number of _unique configurations (people)_

# %%
#destrat out.db +HEADERS -v SIGNALS | awk ' NR != 1 ' | cut -f2- | sort | uniq -c | sort -nr
with pd.option_context('display.max_colwidth', 80):
    print(tbl.groupby('SIGNALS').count())
# Out:
#                                                                                   ID
# SIGNALS
# EEG-Fp1,EEG-Fp2,EEG-AF3,EEG-AF4,EEG-F7,EEG-F5,EEG-F3,EEG-F1,EEG-F2,EEG-F4,EEG...   1
# FP1,FP2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5...   1
# Fp1 REF,Fp2 REF,AF3 REF,AF4 REF,F7 REF,F5 REF,F3 REF,F1 REF,F2 REF,F4 REF,F6 ...   1
# Fp1,Fp2,AF3,AF4,F7,F5,F1,F2,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C1,C2...   1
# Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5...   1
# Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5...  13
# Fp1-(M1+M2)/2,Fp2-(M1+M2)/2,AF3-(M1+M2)/2,AF4-(M1+M2)/2,F7-(M1+M2)/2,F5-(M1+M...   1
# fp1,fp2,af3,af4,f7,f5,f3,f1,f2,f4,f6,f8,ft7,fc5,fc3,fc1,fc2,fc4,fc6,ft8,t7,c5...   1

# %% [markdown]
# Above we will 13 people have the same montage (and ordering in the EDF), whereas 20-13 = 7 people have something different.   Note that the above enumeration treats differently ordered lists as distinct.  If we force a similar order (set `order-signals` to `T`) then we see 14 people have the same ("standard") montage/labels, as seen in the main walkthorugh.

# %%
proj.var( 'order-signals','T' )
res = proj.silent_proc( 'HEADERS signals' ) 
tbl = proj.table( 'HEADERS' )[[ 'ID', 'SIGNALS' ]]
with pd.option_context('display.max_colwidth', 80):
    print(tbl.groupby('SIGNALS').count())
# Out:
#                                                                                   ID
# SIGNALS
# A1 REF,A2 REF,AF3 REF,AF4 REF,AFZ REF,C1 REF,C2 REF,C3 REF,C4 REF,C5 REF,C6 R...   1
# A1,A2,AF3,AF4,AFZ,C1,C2,C3,C4,C5,C6,CP1,CP2,CP3,CP4,CP5,CP6,CPZ,CZ,F1,F2,F3,F...   1
# A1,A2,AF3,AF4,AFZ,C1,C2,C3,C4,C5,C6,CP1,CP2,CP3,CP4,CP5,CP6,CPZ,CZ,F1,F2,F3,F...  14
# A1,A2,AF3,AF4,AFZ,C1,C2,C3,C4,C5,C6,CP1,CP2,CP3,CP4,CP5,CP6,CPZ,F1,F2,F3,F4,F...   1
# AF3-(M1+M2)/2,AF4-(M1+M2)/2,AFZ-(M1+M2)/2,C1-(M1+M2)/2,C2-(M1+M2)/2,C3-(M1+M2...   1
# EEG-A1,EEG-A2,EEG-AF3,EEG-AF4,EEG-AFZ,EEG-C1,EEG-C2,EEG-C3,EEG-C4,EEG-C5,EEG-...   1
# a1,a2,af3,af4,afz,c1,c2,c3,c4,c5,c6,cp1,cp2,cp3,cp4,cp5,cp6,cpz,cz,f1,f2,f3,f...   1

# %% [markdown]
# ### Applying channel aliases

# %% [markdown]
# We'll focus on one individual (`M09`) to illustrate how aliases/sanitization are applied in the lunapi context.
#
# First, given we turned off sanitization in a cell above, we'll expect that attaching this individual will print the original labels (i.e. those in the actual EDF).

# %%
#M09
p = proj.inst( 'M09' )
# Out:
# ___________________________________________________________________
# Processing: M09 | ../work/data/edfs//M09.edf
#  duration 08.08.32, 29312s | time 22.00.00 - 06.08.32 | date 01.01.85
#
#  signals: 57 (of 57) selected in a standard EDF file
#   Fp1-(M1+M2)/2 | Fp2-(M1+M2)/2 | AF3-(M1+M2)/2 | AF4-(M1+M2)/2 | F7-(M1+M2)/2 | F5-(M1+M2)/2 | F3-(M1+M2)/2 | F1-(M1+M2)/2
#   F2-(M1+M2)/2 | F4-(M1+M2)/2 | F6-(M1+M2)/2 | F8-(M1+M2)/2 | FT7-(M1+M2)/2 | FC5-(M1+M2)/2 | FC3-(M1+M2)/2 | FC1-(M1+M2)/2
#   FC2-(M1+M2)/2 | FC4-(M1+M2)/2 | FC6-(M1+M2)/2 | FT8-(M1+M2)/2 | T7-(M1+M2)/2 | C5-(M1+M2)/2 | C3-(M1+M2)/2 | C1-(M1+M2)/2
#   C2-(M1+M2)/2 | C4-(M1+M2)/2 | C6-(M1+M2)/2 | T8-(M1+M2)/2 | TP7-(M1+M2)/2 | CP5-(M1+M2)/2 | CP3-(M1+M2)/2 | CP1-(M1+M2)/2
#   CP2-(M1+M2)/2 | CP4-(M1+M2)/2 | CP6-(M1+M2)/2 | TP8-(M1+M2)/2 | P7-(M1+M2)/2 | P5-(M1+M2)/2 | P3-(M1+M2)/2 | P1-(M1+M2)/2
#   P2-(M1+M2)/2 | P4-(M1+M2)/2 | P6-(M1+M2)/2 | P8-(M1+M2)/2 | PO3-(M1+M2)/2 | PO4-(M1+M2)/2 | O1-(M1+M2)/2 | O2-(M1+M2)/2
#   AFZ-(M1+M2)/2 | FZ-(M1+M2)/2 | FCZ-(M1+M2)/2 | CZ-(M1+M2)/2 | CPZ-(M1+M2)/2 | PZ-(M1+M2)/2 | POz-(M1+M2)/2 | OZ-(M1+M2)/2
#   FPZ-(M1+M2)/2

# %% [markdown]
# If we turn _sanitization_ back on (set to `T`), and repeat the same command, we see the special characters have been replaced.  See the walkthrough for a description of the logic of this.

# %%
proj.var( 'sanitize' , 'T' )
p = proj.inst( 'M09' )
# Out:
# ___________________________________________________________________
# Processing: M09 | ../work/data/edfs//M09.edf
#  duration 08.08.32, 29312s | time 22.00.00 - 06.08.32 | date 01.01.85
#
#  signals: 57 (of 57) selected in a standard EDF file
#   Fp1__M1_M2__2 | Fp2__M1_M2__2 | AF3__M1_M2__2 | AF4__M1_M2__2 | F7__M1_M2__2 | F5__M1_M2__2 | F3__M1_M2__2 | F1__M1_M2__2
#   F2__M1_M2__2 | F4__M1_M2__2 | F6__M1_M2__2 | F8__M1_M2__2 | FT7__M1_M2__2 | FC5__M1_M2__2 | FC3__M1_M2__2 | FC1__M1_M2__2
#   FC2__M1_M2__2 | FC4__M1_M2__2 | FC6__M1_M2__2 | FT8__M1_M2__2 | T7__M1_M2__2 | C5__M1_M2__2 | C3__M1_M2__2 | C1__M1_M2__2
#   C2__M1_M2__2 | C4__M1_M2__2 | C6__M1_M2__2 | T8__M1_M2__2 | TP7__M1_M2__2 | CP5__M1_M2__2 | CP3__M1_M2__2 | CP1__M1_M2__2
#   CP2__M1_M2__2 | CP4__M1_M2__2 | CP6__M1_M2__2 | TP8__M1_M2__2 | P7__M1_M2__2 | P5__M1_M2__2 | P3__M1_M2__2 | P1__M1_M2__2
#   P2__M1_M2__2 | P4__M1_M2__2 | P6__M1_M2__2 | P8__M1_M2__2 | PO3__M1_M2__2 | PO4__M1_M2__2 | O1__M1_M2__2 | O2__M1_M2__2
#   AFZ__M1_M2__2 | FZ__M1_M2__2 | FCZ__M1_M2__2 | CZ__M1_M2__2 | CPZ__M1_M2__2 | PZ__M1_M2__2 | POz__M1_M2__2 | OZ__M1_M2__2
#   FPZ__M1_M2__2

# %% [markdown]
# Finally, we can specify an `@include` list that lists all aliases.   We have the the file `cmaps` with these mappings.

# %%
# %%sh
# head ../work/data/aux/cmaps
# Out:
# alias	Fp1|Fp1-(M1+M2)/2|EEG-Fp1|"Fp1 REF"
# alias	Fp2|Fp2-(M1+M2)/2|EEG-Fp2|"Fp2 REF"
# alias	AF3|AF3-(M1+M2)/2|EEG-AF3|"AF3 REF"
# alias	AF4|AF4-(M1+M2)/2|EEG-AF4|"AF4 REF"
# alias	F7|F7-(M1+M2)/2|EEG-F7|"F7 REF"
# alias	F5|F5-(M1+M2)/2|EEG-F5|"F5 REF"
# alias	F3|F3-(M1+M2)/2|EEG-F3|"F3 REF"
# alias	F1|F1-(M1+M2)/2|EEG-F1|"F1 REF"
# alias	F2|F2-(M1+M2)/2|EEG-F2|"F2 REF"
# alias	F4|F4-(M1+M2)/2|EEG-F4|"F4 REF"

# %% [markdown]
# We can `@include` them:  this is similar to running
#
# ```
# luna s1.lst @../work/data/aux/cmaps ...
# ```
# (except that these special variables _remain set_ in the interactive lunapi environment unless explicitly cleared, i.e. they will contine to apply to any subsequent `inst()` or `attach_edf()` functions that "attach" new signal data).

# %%
proj.include( '../work/data/aux/cmaps' )
# Out:
#   setting alias = Fp1|Fp1-(M1+M2)/2|EEG-Fp1|"Fp1 REF"
#   setting alias = Fp2|Fp2-(M1+M2)/2|EEG-Fp2|"Fp2 REF"
#   setting alias = AF3|AF3-(M1+M2)/2|EEG-AF3|"AF3 REF"
#   setting alias = AF4|AF4-(M1+M2)/2|EEG-AF4|"AF4 REF"
#   setting alias = F7|F7-(M1+M2)/2|EEG-F7|"F7 REF"
#   setting alias = F5|F5-(M1+M2)/2|EEG-F5|"F5 REF"
#   setting alias = F3|F3-(M1+M2)/2|EEG-F3|"F3 REF"
#   setting alias = F1|F1-(M1+M2)/2|EEG-F1|"F1 REF"
#   setting alias = F2|F2-(M1+M2)/2|EEG-F2|"F2 REF"
#   setting alias = F4|F4-(M1+M2)/2|EEG-F4|"F4 REF"
#   setting alias = F6|F6-(M1+M2)/2|EEG-F6|"F6 REF"
#   setting alias = F8|F8-(M1+M2)/2|EEG-F8|"F8 REF"
#   setting alias = FT7|FT7-(M1+M2)/2|EEG-FT7|"FT7 REF"
#   setting alias = FC5|FC5-(M1+M2)/2|EEG-FC5|"FC5 REF"
#   setting alias = FC3|FC3-(M1+M2)/2|EEG-FC3|"FC3 REF"
#   setting alias = FC1|FC1-(M1+M2)/2|EEG-FC1|"FC1 REF"
#   setting alias = FC2|FC2-(M1+M2)/2|EEG-FC2|"FC2 REF"
#   setting alias = FC4|FC4-(M1+M2)/2|EEG-FC4|"FC4 REF"
#   setting alias = FC6|FC6-(M1+M2)/2|EEG-FC6|"FC6 REF"
#   setting alias = FT8|FT8-(M1+M2)/2|EEG-FT8|"FT8 REF"
#   setting alias = T7|T7-(M1+M2)/2|EEG-T7|"T7 REF"
#   setting alias = C5|C5-(M1+M2)/2|EEG-C5|"C5 REF"
#   setting alias = C3|C3-(M1+M2)/2|EEG-C3|"C3 REF"
#   setting alias = C1|C1-(M1+M2)/2|EEG-C1|"C1 REF"
#   setting alias = C2|C2-(M1+M2)/2|EEG-C2|"C2 REF"
#   setting alias = C4|C4-(M1+M2)/2|EEG-C4|"C4 REF"
#   setting alias = C6|C6-(M1+M2)/2|EEG-C6|"C6 REF"
#   setting alias = T8|T8-(M1+M2)/2|EEG-T8|"T8 REF"
#   setting alias = TP7|TP7-(M1+M2)/2|EEG-TP7|"TP7 REF"
#   setting alias = CP5|CP5-(M1+M2)/2|EEG-CP5|"CP5 REF"
#   setting alias = CP3|CP3-(M1+M2)/2|EEG-CP3|"CP3 REF"
#   setting alias = CP1|CP1-(M1+M2)/2|EEG-CP1|"CP1 REF"
#   setting alias = CP2|CP2-(M1+M2)/2|EEG-CP2|"CP2 REF"
#   setting alias = CP4|CP4-(M1+M2)/2|EEG-CP4|"CP4 REF"
#   setting alias = CP6|CP6-(M1+M2)/2|EEG-CP6|"CP6 REF"
#   setting alias = TP8|TP8-(M1+M2)/2|EEG-TP8|"TP8 REF"
#   setting alias = P7|P7-(M1+M2)/2|EEG-P7|"P7 REF"
#   setting alias = P5|P5-(M1+M2)/2|EEG-P5|"P5 REF"
#   setting alias = P3|P3-(M1+M2)/2|EEG-P3|"P3 REF"
#   setting alias = P1|P1-(M1+M2)/2|EEG-P1|"P1 REF"
#   setting alias = P2|P2-(M1+M2)/2|EEG-P2|"P2 REF"
#   setting alias = P4|P4-(M1+M2)/2|EEG-P4|"P4 REF"
#   setting alias = P6|P6-(M1+M2)/2|EEG-P6|"P6 REF"
#   setting alias = P8|P8-(M1+M2)/2|EEG-P8|"P8 REF"
#   setting alias = PO3|PO3-(M1+M2)/2|EEG-PO3|"PO3 REF"
#   setting alias = PO4|PO4-(M1+M2)/2|EEG-PO4|"PO4 REF"
#   setting alias = O1|O1-(M1+M2)/2|EEG-O1|"O1 REF"
#   setting alias = O2|O2-(M1+M2)/2|EEG-O2|"O2 REF"
#   setting alias = AFZ|AFZ-(M1+M2)/2|EEG-AFZ|"AFZ REF"
#   setting alias = FZ|FZ-(M1+M2)/2|EEG-FZ|"FZ REF"
#   setting alias = FCZ|FCZ-(M1+M2)/2|EEG-FCZ|"FCZ REF"
#   setting alias = CZ|CZ-(M1+M2)/2|EEG-CZ|"CZ REF"
#   setting alias = CPZ|CPZ-(M1+M2)/2|EEG-CPZ|"CPZ REF"
#   setting alias = PZ|PZ-(M1+M2)/2|EEG-PZ|"PZ REF"
#   setting alias = POz|POz-(M1+M2)/2|EEG-POz|"POz REF"
#   setting alias = OZ|OZ-(M1+M2)/2|EEG-OZ|"OZ REF"
#   setting alias = A1|A1-(M1+M2)/2|EEG-A1|"A1 REF"
#   setting alias = A2|A2-(M1+M2)/2|EEG-A2|"A2 REF"
#   setting alia
# 63
# s = FPZ|FPZ-(M1+M2)/2|EEG-FPZ|"FPZ REF"
#   setting alias = A1|EEG-A1|"A1 REF"
#   setting alias = A1|M1|EEG-M1|"M1 REF"
#   setting alias = A2|EEG-A2|"A2 REF"
#   setting alias = A2|M2|EEG-M2|"M2 REF"

# %% [markdown]
# If we now attach `M09` again, we should see the _harmonized_ labels.

# %%
p = proj.inst( 'M09' )
# Out:
# ___________________________________________________________________
# Processing: M09 | ../work/data/edfs//M09.edf
#  duration 08.08.32, 29312s | time 22.00.00 - 06.08.32 | date 01.01.85
#
#  signals: 57 (of 57) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   FPZ

# %% [markdown]
# Having set _aliases_ (or other types of mappings, e.g. for annotations) it can be useful to make lunapi tell us what the current "conversion table" looks like.  We can do this with project-level `aliases()`.

# %%
#luna s1.lst @work/data/aux/cmaps -o out.db -s HEADERS
# w/ aliases attached
proj.aliases()
# Out:
#       Type   Preferred Case-insensitive, sanitized alias
# 1       CH          A1                            A1 REF
# 2       CH          A1                      A1__M1_M2__2
# 3       CH          A2                            A2 REF
# 4       CH          A2                      A2__M1_M2__2
# 5       CH         AF3                           AF3 REF
# 6       CH         AF3                     AF3__M1_M2__2
# 7       CH         AF4                           AF4 REF
# 8       CH         AF4                     AF4__M1_M2__2
# 9       CH         AFZ                           AFZ REF
# 10      CH         AFZ                     AFZ__M1_M2__2
# 11      CH          C1                            C1 REF
# 12      CH          C1                      C1__M1_M2__2
# 13      CH          C2                            C2 REF
# 14      CH          C2                      C2__M1_M2__2
# 15      CH          C3                            C3 REF
# 16      CH          C3                      C3__M1_M2__2
# 17      CH          C4                            C4 REF
# 18      CH          C4                      C4__M1_M2__2
# 19      CH          C5                            C5 REF
# 20      CH          C5                      C5__M1_M2__2
# 21      CH          C6                            C6 REF
# 22      CH          C6                      C6__M1_M2__2
# 23      CH         CP1                           CP1 REF
# 24      CH         CP1                     CP1__M1_M2__2
# 25      CH         CP2                           CP2 REF
# 26      CH         CP2                     CP2__M1_M2__2
# 27      CH         CP3                           CP3 REF
# 28      CH         CP3                     CP3__M1_M2__2
# 29      CH         CP4                           CP4 REF
# 30      CH         CP4                     CP4__M1_M2__2
# 31      CH         CP5                           CP5 REF
# 32      CH         CP5                     CP5__M1_M2__2
# 33      CH         CP6                           CP6 REF
# 34      CH         CP6                     CP6__M1_M2__2
# 35      CH         CPZ                           CPZ REF
# 36      CH         CPZ                     CPZ__M1_M2__2
# 37      CH          CZ                            CZ REF
# 38      CH          CZ                      CZ__M1_M2__2
# 39      CH          A1                            EEG_A1
# 40      CH          A2                            EEG_A2
# 41      CH         AF3                           EEG_AF3
# 42      CH         AF4                           EEG_AF4
# 43      CH         AFZ                           EEG_AFZ
# 44      CH          C1                            EEG_C1
# 45      CH          C2                            EEG_C2
# 46      CH          C3                            EEG_C3
# 47      CH          C4                            EEG_C4
# 48      CH          C5                            EEG_C5
# 49      CH          C6                            EEG_C6
# 50      CH         CP1                           EEG_CP1
# 51      CH         CP2                           EEG_CP2
# 52      CH         CP3                           EEG_CP3
# 53      CH         CP4                           EEG_CP4
# 54      CH         CP5                           EEG_CP5
# 55      CH         CP6                           EEG_CP6
# 56      CH         CPZ                           EEG_CPZ
# 57      CH          CZ                            EEG_CZ
# 58      CH          F1                            EEG_F1
# 59      CH          F2                            EEG_F2
# 60      CH          F3                            EEG_F3
# 61      CH          F4                            EEG_F4
# 62      CH          F5                            EEG_F5
# 63      CH          F6                            EEG_F6
# 64      CH          F7                            EEG_F7
# 65      CH          F8                            EEG_F8
# 66      CH         FC1                           EEG_FC1
# 67      CH         FC2                           EEG_FC2
# 68      CH         FC3                           EEG_FC3
# 69      CH         FC4                           EEG_FC4
# 70      CH         FC5                           EEG_FC5
# 71      CH         FC6                           EEG_FC6
# 72      CH         FCZ                           EEG_FCZ
# 73      CH         Fp1                           EEG_FP1
# 74      CH         Fp2                           EEG_FP2
# 75      CH         FPZ                           EEG_FPZ
# 76      CH         FT7                           EEG_FT7
# 77      CH         FT8                           EEG_FT8
# 78      CH          FZ                            EEG_FZ
# 79      CH          A1                            EEG_M1
# 80      CH          A2                            EEG_M2
# 81      CH          O1                            EEG_O1
# 82      CH          O2                            EEG_O2
# 83      CH          OZ                            EEG_OZ
# 84      CH          P1                            EEG_P1
# 85      CH          P2                            EEG_P2
# 86      CH          P3                            EEG_P3
# 87      CH          P4                            EEG_P4
# 88      CH          P5                            EEG_P5
# 89      CH          P6                            EEG_P6
# 90      CH          P7                            EEG_P7
# 91      CH          P8                            EEG_P8
# 92      CH         PO3                           EEG_PO3
# 93      CH         PO4                           EEG_PO4
# 94      CH         POz                           EEG_POZ
# 95      CH          PZ                            EEG_PZ
# 96      CH          T7                            EEG_T7
# 97      CH          T8                            EEG_T8
# 98      CH         TP7                           EEG_TP7
# 99      CH         TP8                           EEG_TP8
# 100     CH          F1                            F1 REF
# 101     CH          F1                      F1__M1_M2__2
# 102     CH          F2                            F2 REF
# 103     CH          F2                      F2__M1_M2__2
# 104     CH          F3                            F3 REF
# 105     CH          F3                      F3__M1_M2__2
# 106     CH          F4                            F4 REF
# 107     CH          F4                      F4__M1_M2__2
# 108     CH          F5                            F5 REF
# 109     CH          F5                      F5__M1_M2__2
# 110     CH          F6                            F6 REF
# 111     CH          F6                      F6__M1_M2__2
# 112     CH          F7                            F7 REF
# 113     CH          F7                      F7__M1_M2__2
# 114     CH          F8                            F8 REF
# 115     CH          F8                      F8__M1_M2__2
# 116     CH         FC1                           FC1 REF
# 117     CH         FC1                     FC1__M1_M2__2
# 118     CH         FC2                           FC2 REF
# 119     CH         FC2                     FC2__M1_M2__2
# 120     CH         FC3                           FC3 REF
# 121     CH         FC3                     FC3__M1_M2__2
# 122     CH         FC4                           FC4 REF
# 123     CH         FC4                     FC4__M1_M2__2
# 124     CH         FC5                           FC5 REF
# 125     CH         FC5                     FC5__M1_M2__2
# 126     CH         FC6                           FC6 REF
# 127     CH         FC6                     FC6__M1_M2__2
# 128     CH         FCZ                           FCZ REF
# 129     CH         FCZ                     FCZ__M1_M2__2
# 130     CH         Fp1                           FP1 REF
# 131     CH         Fp1                     FP1__M1_M2__2
# 132     CH         Fp2                           FP2 REF
# 133     CH         Fp2                     FP2__M1_M2__2
# 134     CH         FPZ                           FPZ REF
# 135     CH         FPZ                     FPZ__M1_M2__2
# 136     CH         FT7                           FT7 REF
# 137     CH         FT7                     FT7__M1_M2__2
# 138     CH         FT8                           FT8 REF
# 139     CH         FT8                     FT8__M1_M2__2
# 140     CH          FZ                            FZ REF
# 141     CH          FZ                      FZ__M1_M2__2
# 142     CH          A1                                M1
# 143     CH          A1                            M1 REF
# 144     CH          A2                                M2
# 145     CH          A2                            M2 REF
# 146     CH          O1                            O1 REF
# 147     CH          O1                      O1__M1_M2__2
# 148     CH          O2                            O2 REF
# 149     CH          O2                      O2__M1_M2__2
# 150     CH          OZ                            OZ REF
# 151     CH          OZ                      OZ__M1_M2__2
# 152     CH          P1                            P1 REF
# 153     CH          P1                      P1__M1_M2__2
# 154     CH          P2                            P2 REF
# 155     CH          P2                      P2__M1_M2__2
# 156     CH          P3                            P3 REF
# 157     CH          P3                      P3__M1_M2__2
# 158     CH          P4                            P4 REF
# 159     CH          P4                      P4__M1_M2__2
# 160     CH          P5                            P5 REF
# 161     CH          P5                      P5__M1_M2__2
# 162     CH          P6                            P6 REF
# 163     CH          P6                      P6__M1_M2__2
# 164     CH          P7                            P7 REF
# 165     CH          P7                      P7__M1_M2__2
# 166     CH          P8                            P8 REF
# 167     CH          P8                      P8__M1_M2__2
# 168     CH         PO3                           PO3 REF
# 169     CH         PO3                     PO3__M1_M2__2
# 170     CH         PO4                           PO4 REF
# 171     CH         PO4                     PO4__M1_M2__2
# 172     CH         POz                           POZ REF
# 173     CH         POz                     POZ__M1_M2__2
# 174     CH          PZ                            PZ REF
# 175     CH          PZ                      PZ__M1_M2__2
# 176     CH          T7                            T7 REF
# 177     CH          T7                      T7__M1_M2__2
# 178     CH          T8                            T8 REF
# 179     CH          T8                      T8__M1_M2__2
# 180     CH         TP7                           TP7 REF
# 181     CH         TP7                     TP7__M1_M2__2
# 182     CH         TP8                           TP8 REF
# 183     CH         TP8                     TP8__M1_M2__2
# 184  ANNOT           L                             LIGHT
# 185  ANNOT           L                            LIGHTS
# 186  ANNOT  lights_off                         LIGHTSOFF
# 187  ANNOT   lights_on                          LIGHTSON
# 188  ANNOT  lights_off                        LIGHTS_OFF
# 189  ANNOT   lights_on                         LIGHTS_ON
# 190  ANNOT           M                        MOVEMENT|6
# 191  ANNOT          N1                          N1_SLEEP
# 192  ANNOT          N2                          N2_SLEEP
# 193  ANNOT          N3                          N3_SLEEP
# 194  ANNOT          N3                                N4
# 195  ANNOT          N3                          N4_SLEEP
# 196  ANNOT          NR                              NREM
# 197  ANNOT          N1                             NREM1
# 198  ANNOT          N1                       NREM1_SLEEP
# 199  ANNOT          N2                             NREM2
# 200  ANNOT          N2                       NREM2_SLEEP
# 201  ANNOT          N3                             NREM3
# 202  ANNOT          N3                       NREM3_SLEEP
# 203  ANNOT          N3                             NREM4
# 204  ANNOT          N3                       NREM4_SLEEP
# 205  ANNOT          NR                        NREM_SLEEP
# 206  ANNOT          NR                          NR_SLEEP
# 207  ANNOT           R                               REM
# 208  ANNOT           R                         REM_SLEEP
# 209  ANNOT           R                       REM_SLEEP|5
# 210  ANNOT          N1                                S1
# 211  ANNOT          N2                                S2
# 212  ANNOT          N3                                S3
# 213  ANNOT          N3                                S4
# 214  ANNOT          N1                     SLEEP_STAGE_1
# 215  ANNOT          N2                     SLEEP_STAGE_2
# 216  ANNOT          N3                     SLEEP_STAGE_3
# 217  ANNOT          N3                     SLEEP_STAGE_4
# 218  ANNOT           ?                     SLEEP_STAGE_?
# 219  ANNOT          NR                     SLEEP_STAGE_N
# 220  ANNOT          N1                    SLEEP_STAGE_N1
# 221  ANNOT          N2                    SLEEP_STAGE_N2
# 222  ANNOT          N3                    SLEEP_STAGE_N3
# 223  ANNOT          N3                    SLEEP_STAGE_N4
# 224  ANNOT          NR                    SLEEP_STAGE_NR
# 225  ANNOT          NR                  SLEEP_STAGE_NREM
# 226  ANNOT           R                     SLEEP_STAGE_R
# 227  ANNOT           R                   SLEEP_STAGE_REM
# 228  ANNOT           W                     SLEEP_STAGE_W
# 229  ANNOT           W                  SLEEP_STAGE_WAKE
# 230  ANNOT          N1                            STAGE1
# 231  ANNOT          N2                            STAGE2
# 232  ANNOT          N3                            STAGE3
# 233  ANNOT          N3                            STAGE4
# 234  ANNOT          NR                            STAGEN
# 235  ANNOT          N1                           STAGEN1
# 236  ANNOT          N2                           STAGEN2
# 237  ANNOT          N3                           STAGEN3
# 238  ANNOT          N3                           STAGEN4
# 239  ANNOT          NR                           STAGENR
# 240  ANNOT          NR                         STAGENREM
# 241  ANNOT          N1                        STAGENREM1
# 242  ANNOT          N2                        STAGENREM2
# 243  ANNOT          N3                        STAGENREM3
# 244  ANNOT           R                            STAGER
# 245  ANNOT           R                          STAGEREM
# 246  ANNOT           W                            STAGEW
# 247  ANNOT          N1                           STAGE_1
# 248  ANNOT          N1                   STAGE_1_SLEEP|1
# 249  ANNOT          N2                           STAGE_2
# 250  ANNOT          N2                   STAGE_2_SLEEP|2
# 251  ANNOT          N3                           STAGE_3
# 252  ANNOT          N3                   STAGE_3_SLEEP|3
# 253  ANNOT          N3                           STAGE_4
# 254  ANNOT          N3                   STAGE_4_SLEEP|4
# 255  ANNOT           ?                           STAGE_?
# 256  ANNOT          NR                           STAGE_N
# 257  ANNOT          N1                          STAGE_N1
# 258  ANNOT          N2                          STAGE_N2
# 259  ANNOT          N3                          STAGE_N3
# 260  ANNOT          N3                          STAGE_N4
# 261  ANNOT          NR                          STAGE_NR
# 262  ANNOT          NR                        STAGE_NREM
# 263  ANNOT          N1                       STAGE_NREM1
# 264  ANNOT          N2                       STAGE_NREM2
# 265  ANNOT          N3                       STAGE_NREM3
# 266  ANNOT          N3                       STAGE_NREM4
# 267  ANNOT           R                           STAGE_R
# 268  ANNOT           R                         STAGE_REM
# 269  ANNOT           W                           STAGE_W
# 270  ANNOT           W                        STAGE_WAKE
# 271  ANNOT           ?                           UNKNOWN
# 272  ANNOT           U                          UNSCORED
# 273  ANNOT           U                        UNSCORED|9
# 274  ANNOT           W                              WAKE
# 275  ANNOT           W                        WAKE_STAGE
# 276  ANNOT           W                            WAKE|0

# %% [markdown]
# Note the above also includes some default stage/annotation mappings hard-coded in Luna (but can be turned off).

# %% [markdown]
# ## Sample rates and units

# %% [markdown]
# Next we'll look at sample rates and units for the channels.  We'll re-run `HEADERS` as we now have the aliases defined, and so the output will be more consistent across channel labels.

# %%
res = proj.silent_proc( 'HEADERS' )

# %%
tbl = proj.table( 'HEADERS' , 'CH' )

# %%
tbl['CH'].unique()
# Out:
# array(['A1', 'A2', 'AF3', 'AF4', 'AFZ', 'C1', 'C2', 'C3', 'C4', 'C5',
#        'C6', 'CP1', 'CP2', 'CP3', 'CP4', 'CP5', 'CP6', 'CPZ', 'CZ', 'F1',
#        'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'FC1', 'FC2', 'FC3',
#        'FC4', 'FC5', 'FC6', 'FCZ', 'FPZ', 'FT7', 'FT8', 'FZ', 'Fp1',
#        'Fp2', 'O1', 'O2', 'OZ', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7',
#        'P8', 'PO3', 'PO4', 'POz', 'PZ', 'T7', 'T8', 'TP7', 'TP8'],
#       dtype=object)

# %% [markdown]
# That is, above we now only see a smaller set of unique labels, as expected.
# We can get a table/count of channel labels (N = number of individuals).

# %%
tbl = tbl[[ 'ID', 'CH', 'SR', 'PDIM' ]]
tbl.groupby('CH').size().reset_index(name='Count')
# Out:
#      CH  Count
# 0    A1     19
# 1    A2     19
# 2   AF3     20
# 3   AF4     20
# 4   AFZ     20
# 5    C1     20
# 6    C2     20
# 7    C3     20
# 8    C4     20
# 9    C5     20
# 10   C6     20
# 11  CP1     20
# 12  CP2     20
# 13  CP3     20
# 14  CP4     20
# 15  CP5     20
# 16  CP6     20
# 17  CPZ     20
# 18   CZ     19
# 19   F1     20
# 20   F2     20
# 21   F3     20
# 22   F4     20
# 23   F5     20
# 24   F6     20
# 25   F7     20
# 26   F8     20
# 27  FC1     20
# 28  FC2     20
# 29  FC3     20
# 30  FC4     20
# 31  FC5     20
# 32  FC6     20
# 33  FCZ     20
# 34  FPZ     20
# 35  FT7     20
# 36  FT8     20
# 37   FZ     20
# 38  Fp1     20
# 39  Fp2     20
# 40   O1     20
# 41   O2     20
# 42   OZ     20
# 43   P1     20
# 44   P2     20
# 45   P3     20
# 46   P4     20
# 47   P5     20
# 48   P6     20
# 49   P7     20
# 50   P8     20
# 51  PO3     20
# 52  PO4     20
# 53  POz     20
# 54   PZ     20
# 55   T7     20
# 56   T8     20
# 57  TP7     20
# 58  TP8     20

# %% [markdown]
# A table of the number of unique channel / unit / sample-rate combinations.

# %%
tbl.groupby([ 'CH', 'SR' , 'PDIM' ]).size().reset_index(name='Count')
# Out:
#       CH     SR PDIM  Count
# 0     A1  128.0   mV      1
# 1     A1  128.0   uV     17
# 2     A1  150.0   uV      1
# 3     A2  128.0   mV      1
# 4     A2  128.0   uV     17
# ..   ...    ...  ...    ...
# 172  TP7  128.0   uV     18
# 173  TP7  150.0   uV      1
# 174  TP8  128.0   mV      1
# 175  TP8  128.0   uV     18
# 176  TP8  150.0   uV      1
#
# [177 rows x 4 columns]

# %% [markdown]
# A table of the number of unique channel unit / sample-rate combinations.

# %%
tbl.groupby([ 'SR' , 'PDIM' ]).size().reset_index(name='Count')
# Out:
#       SR PDIM  Count
# 0  128.0   mV     59
# 1  128.0   uV   1059
# 2  150.0   uV     59

# %% [markdown]
# Listing unit / sample-list per individual for C3 only.

# %%
# destrat out.db +HEADERS -r CH/C3 -v SR PDIM
tbl.loc[ tbl.CH == 'C3' ]
# Out:
#       ID  CH     SR PDIM
# 138  F01  C3  128.0   uV
# 139  F02  C3  150.0   uV
# 140  F03  C3  128.0   mV
# 141  F04  C3  128.0   uV
# 142  F05  C3  128.0   uV
# 143  F06  C3  128.0   uV
# 144  F07  C3  128.0   uV
# 145  F08  C3  128.0   uV
# 146  F09  C3  128.0   uV
# 147  F10  C3  128.0   uV
# 148  M01  C3  128.0   uV
# 149  M02  C3  128.0   uV
# 150  M03  C3  128.0   uV
# 151  M04  C3  128.0   uV
# 152  M05  C3  128.0   uV
# 153  M06  C3  128.0   uV
# 154  M07  C3  128.0   uV
# 155  M08  C3  128.0   uV
# 156  M09  C3  128.0   uV
# 157  M10  C3  128.0   uV

# %% [markdown]
# ## Generating new EDFs

# %% [markdown]
# Given the channel mapping above, we can create a new set of EDFs with mapped labels and we'll also harmonize sample rates and units, and set linked-mastoid referencing while we're at it.
#
# As we know `M09` already has linked-mastoid referencing, we'll `skip` this person from the run below.

# %%
proj.var( 'skip' , 'M09' )
proj.vars()
# Out:
# {'alias': 'A2|M2|EEG-M2|"M2 REF"',
#  'anterio-frontal': 'AF7,AF3,AFZ,AF8,AF4',
#  'anterior': 'FP1,AF7,AF3,F1,F3,F5,F7,FPZ,AFZ,FZ,FP2,AF8,AF4,F2,F4,F6,F8',
#  'central': 'FT7,FC5,FC3,FC1,C1,C3,C5,T7,TP7,CP5,CP3,CP1,CPZ,FCZ,CZ,FT8,FC6,FC4,FC2,C2,C4,C6,T8,TP8,CP6,CP4,CP2',
#  'centro-parietal': 'CP5,CP3,CP1,CPZ,CP6,CP4,CP2',
#  'frontal': 'F1,F3,F5,F7,FZ,F2,F4,F6,F8',
#  'fronto-central': 'FC5,FC3,FC1,FCZ,FC6,FC4,FC2',
#  'keep-spaces': 'T',
#  'left': 'FP1,AF7,AF3,F1,F3,F5,F7,FT7,FC5,FC3,FC1,C1,C3,C5,T7,TP7,CP5,CP3,CP1,P1,P3,P5,P7,P9,PO7,PO3,O1',
#  'mid-central': 'C1,C3,C5,CZ,C2,C4,C6',
#  'midline': 'IZ,OZ,POZ,PZ,CPZ,FPZ,AFZ,FZ,FCZ,CZ',
#  'occiptital': 'O1,IZ,OZ,O2',
#  'order-signals': 'T',
#  'parietal': 'P1,P3,P5,P7,P9,PZ,P2,P4,P6,P8,P10',
#  'parieto-occipital': 'PO7,PO3,POZ,PO8,PO4',
#  'posterior': 'P1,P3,P5,P7,P9,PO7,PO3,O1,IZ,OZ,POZ,PZ,P2,P4,P6,P8,P10,PO8,PO4,O2',
#  'pre-frontal': 'FP1,FPZ,FP2',
#  'right': 'FP2,AF8,AF4,F2,F4,F6,F8,FT8,FC6,FC4,FC2,C2,C4,C6,T8,TP8,CP6,CP4,CP2,P2,P4,P6,P8,P10,PO8,PO4,O2',
#  'sanitize': 'T',
#  'skip': 'M09',
#  'sleep': 'N1,N2,N3,R',
#  'temporal': 'FT7,T7,TP7,FT8,T8,TP8'}

# %% [markdown]
# This does the actual processing - __it may take a couple of minutes to finish__

# %%
res = proj.proc( """ RESAMPLE sr=128
                     uV 
                     REFERENCE sig=${eeg} ref=A1,A2
                     SIGNALS drop=A1,A2
                     WRITE edf-dir=../work/harm1 """ )
# Out:
# ___________________________________________________________________
# Processing: F01 | ../work/data/edfs//F01.edf
#  duration 03.00.30, 10830s | time 22.00.00 - 04.58.00 | date 01.01.85
#
#  signals: 60 (of 60) selected in an EDF+D file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ | EDF Annotations
#   extracting 'EDF Annotations' track from EDF+
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are truly discontinuous
#   writing 58 channels
#   saved new EDF+D, ../work/harm1/F01.edf
# ___________________________________________________________________
# Processing: F02 | ../work/data/edfs//F02.edf
#  duration 07.10.33, 25833s | time 22.00.00 - 05.10.33 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#   resampling channel A1 from sample rate 150 to 128
#   resampling channel A2 from sample rate 150 to 128
#   resampling channel AF3 from sample rate 150 to 128
#   resampling channel AF4 from sample rate 150 to 128
#   resampling channel AFZ from sample rate 150 to 128
#   resampling channel C1 from sample rate 150 to 128
#   resampling channel C2 from sample rate 150 to 128
#   resampling channel C3 from sample rate 150 to 128
#   resampling channel C4 from sample rate 150 to 128
#   resampling channel C5 from sample rate 150 to 128
#   resampling channel C6 from sample rate 150 to 128
#   resampling channel CP1 from sample rate 150 to 128
#   resampling channel CP2 from sample rate 150 to 128
#   resampling channel CP3 from sample rate 150 to 128
#   resampling channel CP4 from sample rate 150 to 128
#   resampling channel CP5 from sample rate 150 to 128
#   resampling channel CP6 from sample rate 150 to 128
#   resampling channel CPZ from sample rate 150 to 128
#   resampling channel CZ from sample rate 150 to 128
#   resampling channel F1 from sample rate 150 to 128
#   resampling channel F2 from sample rate 150 to 128
#   resampling channel F3 from sample rate 150 to 128
#   resampling channel F4 from sample rate 150 to 128
#   resampling channel F5 from sample rate 150 to 128
#   resampling channel F6 from sample rate 150 to 128
#   resampling channel F7 from sample rate 150 to 128
#   resampling channel F8 from sample rate 150 to 128
#   resampling channel FC1 from sample rate 150 to 128
#   resampling channel FC2 from sample rate 150 to 128
#   resampling channel FC3 from sample rate 150 to 128
#   resampling channel FC4 from sample rate 150 to 128
#   resampling channel FC5 from sample rate 150 to 128
#   resampling channel FC6 from sample rate 150 to 128
#   resampling channel FCZ from sample rate 150 to 128
#   resampling channel FPZ from sample rate 150 to 128
#   resampling channel FT7 from sample rate 150 to 128
#   resampling channel FT8 from sample rate 150 to 128
#   resampling channel FZ from sample rate 150 to 128
#   resampling channel Fp1 from sample rate 150 to 128
#   resampling channel Fp2 from sample rate 150 to 128
#   resampling channel O1 from sample rate 150 to 128
#   resampling channel O2 from sample rate 150 to 128
#   resampling channel OZ from sample rate 150 to 128
#   resampling channel P1 from sample rate 150 to 128
#   resampling channel P2 from sample rate 150 to 128
#   resampling channel P3 from sample rate 150 to 128
#   resampling channel P4 from sample rate 150 to 128
#   resampling channel P5 from sample rate 150 to 128
#   resampling channel P6 from sample rate 150 to 128
#   resampling channel P7 from sample rate 150 to 128
#   resampling channel P8 from sample rate 150 to 128
#   resampling channel PO3 from sample rate 150 to 128
#   resampling channel PO4 from sample rate 150 to 128
#   resampling channel POz from sample rate 150 to 128
#   resampling channel PZ from sample rate 150 to 128
#   resampling channel T7 from sample rate 150 to 128
#   resampling channel T8 from sample rate 150 to 128
#   resampling channel TP7 from sample rate 150 to 128
#   resampling channel TP8 from sample rate 150 to 128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/F02.edf
# ___________________________________________________________________
# Processing: F03 | ../work/data/edfs//F03.edf
#  duration 07.15.24, 26124s | time 22.00.00 - 05.15.24 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#   rescaled A1 to uV
#   rescaled A2 to uV
#   rescaled AF3 to uV
#   rescaled AF4 to uV
#   rescaled AFZ to uV
#   rescaled C1 to uV
#   rescaled C2 to uV
#   rescaled C3 to uV
#   rescaled C4 to uV
#   rescaled C5 to uV
#   rescaled C6 to uV
#   rescaled CP1 to uV
#   rescaled CP2 to uV
#   rescaled CP3 to uV
#   rescaled CP4 to uV
#   rescaled CP5 to uV
#   rescaled CP6 to uV
#   rescaled CPZ to uV
#   rescaled CZ to uV
#   rescaled F1 to uV
#   rescaled F2 to uV
#   rescaled F3 to uV
#   rescaled F4 to uV
#   rescaled F5 to uV
#   rescaled F6 to uV
#   rescaled F7 to uV
#   rescaled F8 to uV
#   rescaled FC1 to uV
#   rescaled FC2 to uV
#   rescaled FC3 to uV
#   rescaled FC4 to uV
#   rescaled FC5 to uV
#   rescaled FC6 to uV
#   rescaled FCZ to uV
#   rescaled FPZ to uV
#   rescaled FT7 to uV
#   rescaled FT8 to uV
#   rescaled FZ to uV
#   rescaled Fp1 to uV
#   rescaled Fp2 to uV
#   rescaled O1 to uV
#   rescaled O2 to uV
#   rescaled OZ to uV
#   rescaled P1 to uV
#   rescaled P2 to uV
#   rescaled P3 to uV
#   rescaled P4 to uV
#   rescaled P5 to uV
#   rescaled P6 to uV
#   rescaled P7 to uV
#   rescaled P8 to uV
#   rescaled PO3 to uV
#   rescaled PO4 to uV
#   rescaled POz to uV
#   rescaled PZ to uV
#   rescaled T7 to uV
#   rescaled T8 to uV
#   rescaled TP7 to uV
#   rescaled TP8 to uV
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/F03.edf
# ___________________________________________________________________
# Processing: F04 | ../work/data/edfs//F04.edf
#  duration 07.18.42, 26322s | time 22.00.00 - 05.18.42 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/F04.edf
# ___________________________________________________________________
# Processing: F05 | ../work/data/edfs//F05.edf
#  duration 07.28.26, 26906s | time 22.00.00 - 05.28.26 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/F05.edf
# ___________________________________________________________________
# Processing: F06 | ../work/data/edfs//F06.edf
#  duration 06.48.30, 24510s | time 22.00.00 - 04.48.30 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/F06.edf
# ___________________________________________________________________
# Processing: F07 | ../work/data/edfs//F07.edf
#  duration 07.52.06, 28326s | time 22.00.00 - 05.52.06 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/F07.edf
# ___________________________________________________________________
# Processing: F08 | ../work/data/edfs//F08.edf
#  duration 07.01.25, 25285s | time 22.00.00 - 05.01.25 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/F08.edf
# ___________________________________________________________________
# Processing: F09 | ../work/data/edfs//F09.edf
#  duration 06.29.53, 23393s | time 22.00.00 - 04.29.53 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/F09.edf
# ___________________________________________________________________
# Processing: F10 | ../work/data/edfs//F10.edf
#  duration 07.40.46, 27646s | time 22.00.00 - 05.46.23 | date 01.01.85
#
#  signals: 60 (of 60) selected in an EDF+D file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   A1 | A2 | FPZ | EDF Annotations
#   extracting 'EDF Annotations' track from EDF+
#  ..................................................................
#  CMD #1: RESAMPLE
#    options: sig=* sr=128
#  ..................................................................
#  CMD #2: uV
#    options: sig=*
#  ..................................................................
#  CMD #3: REFERENCE
#    options: ref=A1,A2 sig=Fp1,Fp2,AF3,AF4,F7,F5,F3,F1,F2,F4,F6,F8,FT7,FC5,FC3,FC1,FC2,FC4,FC6,FT8,T7,C5,C3,C1,C2,C4,C6,T8,TP7,CP5,CP3,CP1,CP2,CP4,CP6,TP8,P7,P5,P3,P1,P2,P4,P6,P8,PO3,PO4,O1,O2,AFZ,FZ,FCZ,CZ,CPZ,PZ,POz,OZ,FPZ
#   referencing AF3 AF4 AFZ C1 C2 C3 C4 C5 C6 CP1 CP2 CP3 CP4 CP5 CP6 CPZ CZ F1 F2 F3 F4 F5 F6 F7 F8 FC1 FC2 FC3 FC4 FC5 FC6 FCZ FPZ FT7 FT8 FZ Fp1 Fp2 O1 O2 OZ P1 P2 P3 P4 P5 P6 P7 P8 PO3 PO4 POz PZ T7 T8 TP7 TP8 with respect to the average of A1 A2
#  ..................................................................
#  CMD #4: SIGNALS
#    options: drop=A1,A2 sig=*
#   dropping channels: A1 A2
#  ..................................................................
#  CMD #5: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are truly discontinuous
#   writing 58 channels
#   saved new EDF+D, ../work/harm1/F10.edf
# ___________________________________________________________________
# Processing: M01 | ../work/data/edfs//M01.edf
#  duration 07.18.05, 26285s | time 22.00.00 - 05.18.05 | date 01.01.85
#
#  signals: 59 (of 59) selected in a standard EDF

# %%
Assuming this completes, this should have added 19 EDFs to `../work/harm1/`.

# %%
# %%sh
# ls -lR ../work/harm1
# Out:
# total 15320144
# -rw-r--r--@ 1 smp37  staff  158371364 Sep 11 10:59 F01.edf
# -rw-r--r--@ 1 smp37  staff  376969984 Sep 11 11:00 F02.edf
# -rw-r--r--@ 1 smp37  staff  381216256 Sep 11 11:00 F03.edf
# -rw-r--r--@ 1 smp37  staff  384105472 Sep 11 11:00 F04.edf
# -rw-r--r--@ 1 smp37  staff  392627200 Sep 11 11:00 F05.edf
# -rw-r--r--@ 1 smp37  staff  357664768 Sep 11 11:01 F06.edf
# -rw-r--r--@ 1 smp37  staff  413347840 Sep 11 11:01 F07.edf
# -rw-r--r--@ 1 smp37  staff  368973568 Sep 11 11:01 F08.edf
# -rw-r--r--@ 1 smp37  staff  341365504 Sep 11 11:01 F09.edf
# -rw-r--r--@ 1 smp37  staff  404254916 Sep 11 11:01 F10.edf
# -rw-r--r--@ 1 smp37  staff  383565568 Sep 11 11:01 M01.edf
# -rw-r--r--@ 1 smp37  staff  387622144 Sep 11 11:01 M02.edf
# -rw-r--r--@ 1 smp37  staff  410633728 Sep 11 11:02 M03.edf
# -rw-r--r--@ 1 smp37  staff  409049344 Sep 11 11:02 M04.edf
# -rw-r--r--@ 1 smp37  staff  408663808 Sep 11 11:02 M05.edf
# -rw-r--r--@ 1 smp37  staff  399894016 Sep 11 11:02 M06.edf
# -rw-r--r--@ 1 smp37  staff  437191168 Sep 11 11:02 M07.edf
# -rw-r--r--@ 1 smp37  staff  429895168 Sep 11 11:02 M08.edf
# -rw-r--r--@ 1 smp37  staff  427735552 Sep 11 11:03 M09.edf
# -rw-r--r--@ 1 smp37  staff  390948896 Sep 11 11:03 M10.edf

# %% [markdown]
# Now we will add the final EDF for `M09` which we are handling differently.

# %%
# now handle M09 : first clear the `skip` variable
proj.clear_vars( 'skip' )
#luna s1.lst @work/data/aux/cmaps id=M09   -s WRITE edf-dir=work/harm1
p = proj.inst( 'M09' )
p.eval( 'WRITE edf-dir=../work/harm1' )
# Out:
# ___________________________________________________________________
# Processing: M09 | ../work/data/edfs//M09.edf
#  duration 08.08.32, 29312s | time 22.00.00 - 06.08.32 | date 01.01.85
#
#  signals: 57 (of 57) selected in a standard EDF file
#   Fp1 | Fp2 | AF3 | AF4 | F7 | F5 | F3 | F1
#   F2 | F4 | F6 | F8 | FT7 | FC5 | FC3 | FC1
#   FC2 | FC4 | FC6 | FT8 | T7 | C5 | C3 | C1
#   C2 | C4 | C6 | T8 | TP7 | CP5 | CP3 | CP1
#   CP2 | CP4 | CP6 | TP8 | P7 | P5 | P3 | P1
#   P2 | P4 | P6 | P8 | PO3 | PO4 | O1 | O2
#   AFZ | FZ | FCZ | CZ | CPZ | PZ | POz | OZ
#   FPZ
#  ..................................................................
#  CMD #1: WRITE
#    options: edf-dir=../work/harm1 sig=*
#   no epoch mask set, no restructuring needed
#   data are not truly discontinuous
#   writing as a standard EDF
#   writing 57 channels
#   saved new EDF, ../work/harm1/M09.edf
#   Command Strata
# 0   WRITE     BL

# %% [markdown]
# Now we should have all 20 EDFs present.

# %%
# %%sh
# ls ../work/harm1
# Out:
# F01.edf
# F02.edf
# F03.edf
# F04.edf
# F05.edf
# F06.edf
# F07.edf
# F08.edf
# F09.edf
# F10.edf
# M01.edf
# M02.edf
# M03.edf
# M04.edf
# M05.edf
# M06.edf
# M07.edf
# M08.edf
# M09.edf
# M10.edf

# %% [markdown]
# Next, we'll go to look at [the annotations](06_anns.ipynb).
