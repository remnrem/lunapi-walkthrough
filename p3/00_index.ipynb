# %% [markdown]
# URL index: [Home](https://zzz.bwh.harvard.edu/luna-walkthrough/) | [Data](https://zzz.bwh.harvard.edu/luna-walkthrough/data/) | [S1. File QC](https://zzz.bwh.harvard.edu/luna-walkthrough/p1/) | [S2. Signal QC](https://zzz.bwh.harvard.edu/luna-walkthrough/p2) | [S3. Staging](https://zzz.bwh.harvard.edu/luna-walkthrough/p3) | [S4. Artifacts](https://zzz.bwh.harvard.edu/luna-walkthrough/p4) | [S5. Analysis](https://zzz.bwh.harvard.edu/luna-walkthrough/p5)
#
# Notebook index: [Index](../00_index.ipynb) | [S1. File QC](../p1/00_index.ipynb) | [S2. Signal QC](../p2/00_index.ipynb) | [S3. Staging](../p3/00_index.ipynb) | [S4. Artifacts](../p4/00_index.ipynb) | [S5. Analysis](../p5/00_index.ipynb)
#
# ---

# %% [markdown]
# # Step 3: working with staging annotations
#
# Walkthrough URL = [https://zzz.bwh.harvard.edu/luna-walkthrough/p3/](https://zzz.bwh.harvard.edu/luna-walkthrough/p3/)
#
# ---

# %% [markdown]
# We next look at the (manually scored) stage annotations included with these EDFs:
#
#  - some simple descriptive statistics on the annotations present
#
#  - generating and visualizing hypnogram-based statistics
#
#  - evaluating signal/staging consistency/quality using the SOAP command
#
#  - in parallel, using Luna's automated staging module POPS in place of the manual stagig

# %% [markdown]
# Let's start by looking at the [annotation descriptives](01_annots.ipynb).
