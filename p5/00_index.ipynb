# %% [markdown]
# URL index: [Home](https://zzz.bwh.harvard.edu/luna-walkthrough/) | [Data](https://zzz.bwh.harvard.edu/luna-walkthrough/data/) | [S1. File QC](https://zzz.bwh.harvard.edu/luna-walkthrough/p1/) | [S2. Signal QC](https://zzz.bwh.harvard.edu/luna-walkthrough/p2) | [S3. Staging](https://zzz.bwh.harvard.edu/luna-walkthrough/p3) | [S4. Artifacts](https://zzz.bwh.harvard.edu/luna-walkthrough/p4) | [S5. Analysis](https://zzz.bwh.harvard.edu/luna-walkthrough/p5)
#
# Notebook index: [Index](../00_index.ipynb) | [S1. File QC](../p1/00_index.ipynb) | [S2. Signal QC](../p2/00_index.ipynb) | [S3. Staging](../p3/00_index.ipynb) | [S4. Artifacts](../p4/00_index.ipynb) | [S5. Analysis](../p5/00_index.ipynb)
#
# ---

# %% [markdown]
# # Step 5: Analysis
#
# Walkthrough URL = [https://zzz.bwh.harvard.edu/luna-walkthrough/p5/](https://zzz.bwh.harvard.edu/luna-walkthrough/p5/)
#
# ---
#
# Having completed validation and reformatting of input files, followed by signal-level QC, staging/annotation QC and interpolation, we are now ready to embark on the analysis of these data.

# %% [markdown]
# We'll briefly consider ten areas of analysis:
#
# | Domain | Description|
# |----|-----|
# |[Macro-architecture](001_macro.ipynb) 	|Quantifying sleep macro-architecture|
# |[Time/frequency analyses](002_tf.ipynb)  |	Spectral analyses, includng Welch, multi-taper and IRASA methods|
# |[Ultradian dynamics](003_dynam.ipynb) | 	Cycle-based and epoch-based NREM dynamics|
# |[Connectivity](004_conn.ipynb)  	|Time-domain and spectral (phase-slope index) sensor-space connectivity|
# |[Dimension reduction](005_psc.ipynb)  |	Principal spectral components|
# |[NREM transients](006_spso.ipynb)  |	Spindle and slow oscillation detection|
# |[Age prediction](007_pad.ipynb)  |	Model-based predictive analysis|
# |[Linear models](008_assoc.ipynb)  	|General and cluster-based linear models|
# |[Peri-event statistics](009_peri.ipynb)  	|Event-locked signal quantification |
# |[Interval-based analysis](010_overlap.ipynb)  | Time-domain empirical analysis of events |

# %% [markdown]
# ---
# Let's [begin!](001_macro.ipynb)
