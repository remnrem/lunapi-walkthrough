# %% [markdown]
# URL index: [Home](https://zzz.bwh.harvard.edu/luna-walkthrough/) | [Data](https://zzz.bwh.harvard.edu/luna-walkthrough/data/) | [S1. File QC](https://zzz.bwh.harvard.edu/luna-walkthrough/p1/) | [S2. Signal QC](https://zzz.bwh.harvard.edu/luna-walkthrough/p2) | [S3. Staging](https://zzz.bwh.harvard.edu/luna-walkthrough/p3) | [S4. Artifacts](https://zzz.bwh.harvard.edu/luna-walkthrough/p4) | [S5. Analysis](https://zzz.bwh.harvard.edu/luna-walkthrough/p5)
#
# Notebook index: [Index](../00_index.ipynb) | [S1. File QC](../p1/00_index.ipynb) | [S2. Signal QC](../p2/00_index.ipynb) | [S3. Staging](../p3/00_index.ipynb) | [S4. Artifacts](../p4/00_index.ipynb) | [S5. Analysis](../p5/00_index.ipynb)
#
# ---

# %% [markdown]
# # Step 4: Epoch-level artifact detection/interpolation
#
# Walkthrough URL = [https://zzz.bwh.harvard.edu/luna-walkthrough/p4/](https://zzz.bwh.harvard.edu/luna-walkthrough/p4/)
#
# ---

# %% [markdown]
# In this last step of QC, we'll perform three major steps:
#
#  - create a revised project (harm1 -> harm2) in which we deal with the remaining injected manipulations of signals and annotations
#
#  - we'll then run epoch-level interpolation to drop and re-impute bad epochs and/or whole channels
#
#  - finally, we review Hjpoth and PSD plots of pre- and post-interpolation datasets
#
# Having done that, we'll finally emarbk on the analytic steps of this walkthrough with our final, cleaned dataset.

# %% [markdown]
# First, we need to [create the revised project](01_harm2.ipynb).
